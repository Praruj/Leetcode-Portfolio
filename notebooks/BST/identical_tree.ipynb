# %% [markdown]
# ## Identical Sub- Trees
#
# - Time complexity : $O(n)$

# %%
class Node:

    def __init__(self,data):
        self.data=data
        self.left=None          # pointer to left child
        self.right=None         # pointer to right child
        

    def is_identical(p,q):
        # Base case : If either (or both) are None
        if p is None or q is None:
            return p==q

        isleftsame=is_identical(p.left,q.left)
        isrightsame=is_identical(p.right,q.right)

        return isleftsame and isrightsame and p.data==r.data

# %% [markdown]
# ## Subtree of Another Tree

# %%
def subtree(root,subroot):
    if not subtree:    # if subroot is empty , its technically a subtree of anything. 
        return Tree

    if not root:        # If root is empty and subroot isnt, its impossible.
        return False
    
    if root.data==subroot.data and is_identical(root,subroot):
        return True

    return subtree(root.left,subroot) or subtree(root.right,subroot)

# %% [markdown]
# **Complexity Analysis**
#
# - $O(M*N)$ : where N is number of nodes in main tree and M is number of nodes in subroot.
