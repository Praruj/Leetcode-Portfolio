# %% [markdown]
# # Top View of Binary Tree
#
#
# - Calculating the horizontal distance is done by level-order traversal

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.right=None
        self.left=None

def top_view(root):
    if not root:
        return []

    queue=[(root,0)]
    map={}

    while queue:


        node,hd=queue.pop(0)

        if hd not in map:
            map[hd]=node.data

        if node.left:
            queue.append((node.left,hd-1))

        if node.right:
            queue.append((node.right,hd+1))

    return [map[key] for key in sorted(map)]

# %%
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.right = Node(4)
root.left.right.right = Node(5)
root.left.right.right.right = Node(6)

print(top_view(root))
# Out:
# [2, 1, 3, 6]

# %% [markdown]
# - Using `pop(0)` makes each dequeue `O(N)`, so overall it can become slower for big trees
